# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_03ac84cdc3bc4eaa9d86485ecd9b4d65 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='Y8XltIqCRiOdnu3KAZWK2j_JGf6lVH0EMQtdPkuEwdnK',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

streaming_body_1 = client_03ac84cdc3bc4eaa9d86485ecd9b4d65.get_object(Bucket='fertilizersrecommendationsystemfo-donotdelete-pr-4stzrjkbijajdm', Key='Fertilizers_Recommendation_ System_For_Disease_ Prediction.zip')['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/

# %%
ls
# Out:
# 'Dataset Plant Disease'/

# %%
from io import BytesIO
import zipfile
unzip=zipfile.ZipFile(BytesIO(streaming_body_1.read()),'r')
file_paths=unzip.namelist()
for path in file_paths:
    unzip.extract(path)

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(rescale=1./255,zoom_range=0.2,horizontal_flip=True,vertical_flip=False)

test_datagen=ImageDataGenerator(rescale=1./255)

# %%
x_train=train_datagen.flow_from_directory(r"/home/wsuser/work/Dataset Plant Disease/fruit-dataset/fruit-dataset/train",target_size=(64,64),
                                        class_mode='categorical',batch_size=24)
# Out:
# Found 5384 images belonging to 6 classes.

# %%
x_test=test_datagen.flow_from_directory(r"/home/wsuser/work/Dataset Plant Disease/fruit-dataset/fruit-dataset/test",target_size=(64,64),
                                        class_mode='categorical',batch_size=24)

x_train.class_indices
# Out:
# Found 1686 images belonging to 6 classes.
# {'Apple___Black_rot': 0,
#  'Apple___healthy': 1,
#  'Corn_(maize)___Northern_Leaf_Blight': 2,
#  'Corn_(maize)___healthy': 3,
#  'Peach___Bacterial_spot': 4,
#  'Peach___healthy': 5}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Convolution2D,MaxPooling2D,Flatten

# %%
model=Sequential()

# %%
model.add(Convolution2D(32,(3,3),input_shape=(64,64,3),activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  flatten (Flatten)           (None, 30752)             0
#
# ...
# Total params: 896
# Trainable params: 896
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(Dense(300,activation='relu'))
model.add(Dense(150,activation='relu'))

# %%
model.add(Dense(6,activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

len(x_train)
# Out:
# 225

# %%
model.fit_generator(x_train,steps_per_epoch=len(x_train),validation_data=x_test,validation_steps=len(x_test),epochs=10)
# Out:
# /tmp/wsuser/ipykernel_280/1582812018.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(x_train,steps_per_epoch=len(x_train),validation_data=x_test,validation_steps=len(x_test),epochs=10)
# Epoch 1/10
# 225/225 [==============================] - 33s 146ms/step - loss: 0.5315 - accuracy: 0.8113 - val_loss: 0.2836 - val_accuracy: 0.8944
# Epoch 2/10
# 225/225 [==============================] - 32s 140ms/step - loss: 0.2595 - accuracy: 0.9069 - val_loss: 0.2284 - val_accuracy: 0.9104
# Epoch 3/10
# 225/225 [==============================] - 31s 137ms/step - loss: 0.1853 - accuracy: 0.9352 - val_loss: 0.1298 - val_accuracy: 0.9549
# Epoch 4/10
# 225/225 [==============================] - 30s 134ms/step - loss: 0.1679 - accuracy: 0.9411 - val_loss: 0.1360 - val_accuracy: 0.9549
# Epoch 5/10
# ...

# %%
model.save('fruit.h5')

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
#load the model
model=load_model('fruit.h5')

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
ls
# Out:
# 'Dataset Plant Disease'/   fruit.h5

# %%
img=image.load_img(r"/home/wsuser/work/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___healthy/00fca0da-2db3-481b-b98a-9b67bb7b105c___RS_HL 7708.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/wsuser/ipykernel_280/1819606912.py in <module>
# ----> 1 img=image.load_img(r"/home/wsuser/work/Dataset Plant Disease/fruit.h5/fruit-dataset/fruit-dataset/test/Apple___healthy/00fca0da-2db3-481b-b98a-9b67bb7b105c___RS_HL 7708.jpg")
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     311       ValueError: if interpolation method is not supported.
#     312   """
# --> 313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
#     314                         target_size=target_size, interpolation=interpolation)
#     315
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
# ...

# %%
img=image.load_img(r"/home/wsuser/work/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple__Black_rot/00e909aa-e3ae-4558-9961-336bb0f35db3___JR_FrgE.S 8593.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/wsuser/ipykernel_280/2257741257.py in <module>
# ----> 1 img=image.load_img(r"/home/wsuser/work/'Dataset Plant Disease'/fruit-dataset/fruit-dataset/test/Apple__Black_rot/00e909aa-e3ae-4558-9961-336bb0f35db3___JR_FrgE.S 8593.jpg")
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     311       ValueError: if interpolation method is not supported.
#     312   """
# --> 313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
#     314                         target_size=target_size, interpolation=interpolation)
#     315
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
# ...

# %%
img=image.load_img(r"/home/wsuser/work/Dataset Plant Disease/fruit-dataset/fruit_dataset/test/Apple__Black_rot/00e909aa-e3ae-4558-9961-336bb0f35db3___JR_FrgE.S 8593.jpeg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/wsuser/ipykernel_280/3422473068.py in <module>
# ----> 1 img=image.load_img(r"/home/wsuser/work/Dataset Plant Disease/fruit-dataset/fruit_dataset/test/Apple__Black_rot/00e909aa-e3ae-4558-9961-336bb0f35db3___JR_FrgE.S 8593.jpeg")
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     311       ValueError: if interpolation method is not supported.
#     312   """
# --> 313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
#     314                         target_size=target_size, interpolation=interpolation)
#     315
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
# ...

# %%
img
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/wsuser/ipykernel_280/2486947686.py in <module>
# ----> 1 img
#
# NameError: name 'img' is not defined

# %%
img=image.load_img(r"/home/wsuser/work/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___Black_rot/00e909aa-e3ae-4558-9961-336bb0f35db3___JR_FrgE.S 8593.jpeg",target_size=(64,64))
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/wsuser/ipykernel_280/1293241842.py in <module>
# ----> 1 img=image.load_img(r"/home/wsuser/work/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___Black_rot/00e909aa-e3ae-4558-9961-336bb0f35db3___JR_FrgE.S 8593.jpeg",target_size=(64,64))
#       2 img
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     311       ValueError: if interpolation method is not supported.
#     312   """
# --> 313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
#     314                         target_size=target_size, interpolation=interpolation)
#     315
#
# ...
